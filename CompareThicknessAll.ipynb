# %%
# Loading  libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
from scipy.optimize import curve_fit

font=FontProperties()
font.set_family('serif')
font.set_style('normal')

# %%
#===== loading Data =======
data=np.loadtxt('datosCNRCdTe1000um.txt')
data2=np.loadtxt('datosCNRCdTe500um.txt')
data3=np.loadtxt('datosCNRCdTe200um.txt')
data4=np.loadtxt('datosCNRGaAs1000um.txt')
data5=np.loadtxt('datosCNRGaAs500um.txt')
data6=np.loadtxt('datosCNRGaAs200um.txt')
data7=np.loadtxt('datosCNRSe1000um.txt')
data8=np.loadtxt('datosCNRSe500um.txt')
data9=np.loadtxt('datosCNRSe200um.txt')
data10=np.loadtxt('datosCNRMAPbI31000um.txt')
data11=np.loadtxt('datosCNRMAPbI3500um.txt')
data12=np.loadtxt('datosCNRMAPbI3200um.txt')
data13=np.loadtxt('datosCNRSi1000um.txt')
data14=np.loadtxt('datosCNRSi500um.txt')
data15=np.loadtxt('datosCNRSi200um.txt')

# %%
#====== Cargando Datos ===========

x1=data[:,0]
ex1=data[:,1]
y1=data[:,2]
ey1=data[:,3]

x2=data2[:,0]
ex2=data2[:,1]
y2=data2[:,2]
ey2=data2[:,3]

x3=data3[:,0]
ex3=data3[:,1]
y3=data3[:,2]
ey3=data3[:,3]

x4=data4[:,0]
ex4=data4[:,1]
y4=data4[:,2]
ey4=data4[:,3]

x5=data5[:,0]
ex5=data5[:,1]
y5=data5[:,2]
ey5=data5[:,3]

x6=data6[:,0]
ex6=data6[:,1]
y6=data6[:,2]
ey6=data6[:,3]

x7=data7[:,0]
ex7=data7[:,1]
y7=data7[:,2]
ey7=data7[:,3]

x8=data8[:,0]
ex8=data8[:,1]
y8=data8[:,2]
ey8=data8[:,3]

x9=data9[:,0]
ex9=data9[:,1]
y9=data9[:,2]
ey9=data9[:,3]

x10=data10[:,0]
ex10=data10[:,1]
y10=data10[:,2]
ey10=data10[:,3]

x11=data11[:,0]
ex11=data11[:,1]
y11=data11[:,2]
ey11=data11[:,3]

x12=data12[:,0]
ex12=data12[:,1]
y12=data12[:,2]
ey12=data12[:,3]

x13=data13[:,0]
ex13=data13[:,1]
y13=data13[:,2]
ey13=data13[:,3]

x14=data14[:,0]
ex14=data14[:,1]
y14=data14[:,2]
ey14=data14[:,3]

x15=data15[:,0]
ex15=data15[:,1]
y15=data15[:,2]
ey15=data15[:,3]

# %%
#=============== fits ==================
#=========  Linear function ============
def reg_lin(x,a,b):
    return a+b*x

pars,cov=curve_fit(f=reg_lin,xdata=x1,ydata=y1,sigma=ey1,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p2pars,cov2=curve_fit(f=reg_lin,xdata=x2,ydata=y2,sigma=ey2,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p3pars,cov3=curve_fit(f=reg_lin,xdata=x3,ydata=y3,sigma=ey3,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)

p4pars,cov4=curve_fit(f=reg_lin,xdata=x4,ydata=y4,sigma=ey4,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p5pars,cov5=curve_fit(f=reg_lin,xdata=x5,ydata=y5,sigma=ey5,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p6pars,cov6=curve_fit(f=reg_lin,xdata=x6,ydata=y6,sigma=ey6,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)

p7pars,cov7=curve_fit(f=reg_lin,xdata=x7,ydata=y7,sigma=ey7,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p8pars,cov8=curve_fit(f=reg_lin,xdata=x8,ydata=y8,sigma=ey8,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p9pars,cov9=curve_fit(f=reg_lin,xdata=x9,ydata=y9,sigma=ey9,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)

p10pars,cov10=curve_fit(f=reg_lin,xdata=x10,ydata=y10,sigma=ey10,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p11pars,cov11=curve_fit(f=reg_lin,xdata=x11,ydata=y11,sigma=ey11,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p12pars,cov12=curve_fit(f=reg_lin,xdata=x12,ydata=y12,sigma=ey12,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)

p13pars,cov13=curve_fit(f=reg_lin,xdata=x13,ydata=y13,sigma=ey13,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p14pars,cov14=curve_fit(f=reg_lin,xdata=x14,ydata=y14,sigma=ey14,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)
p15pars,cov15=curve_fit(f=reg_lin,xdata=x15,ydata=y15,sigma=ey15,p0=[0,0],bounds=(-np.inf,np.inf),absolute_sigma=True)


#fit Standard Deviations
stdevs=np.sqrt(np.diag(cov))
stdevs2=np.sqrt(np.diag(cov2))
stdevs3=np.sqrt(np.diag(cov3))
stdevs4=np.sqrt(np.diag(cov4))
stdevs5=np.sqrt(np.diag(cov5))
stdevs6=np.sqrt(np.diag(cov6))
stdevs7=np.sqrt(np.diag(cov7))
stdevs8=np.sqrt(np.diag(cov8))
stdevs9=np.sqrt(np.diag(cov9))
stdevs10=np.sqrt(np.diag(cov10))
stdevs11=np.sqrt(np.diag(cov11))
stdevs12=np.sqrt(np.diag(cov12))
stdevs13=np.sqrt(np.diag(cov13))
stdevs14=np.sqrt(np.diag(cov14))
stdevs15=np.sqrt(np.diag(cov15))


# Calculate uncertanties
d_a=np.sqrt(cov[0][0])
d_b=np.sqrt(cov[1][1])

d_a2=np.sqrt(cov2[0][0])
d_b2=np.sqrt(cov2[1][1])

d_a3=np.sqrt(cov3[0][0])
d_b3=np.sqrt(cov3[1][1])

d_a4=np.sqrt(cov4[0][0])
d_b4=np.sqrt(cov4[1][1])

d_a5=np.sqrt(cov5[0][0])
d_b5=np.sqrt(cov5[1][1])

d_a6=np.sqrt(cov6[0][0])
d_b6=np.sqrt(cov6[1][1])

d_a7=np.sqrt(cov7[0][0])
d_b7=np.sqrt(cov7[1][1])

d_a8=np.sqrt(cov8[0][0])
d_b8=np.sqrt(cov8[1][1])

d_a9=np.sqrt(cov9[0][0])
d_b9=np.sqrt(cov9[1][1])

d_a10=np.sqrt(cov10[0][0])
d_b10=np.sqrt(cov10[1][1])

d_a11=np.sqrt(cov11[0][0])
d_b11=np.sqrt(cov11[1][1])

d_a12=np.sqrt(cov12[0][0])
d_b12=np.sqrt(cov12[1][1])

d_a13=np.sqrt(cov13[0][0])
d_b13=np.sqrt(cov13[1][1])

d_a14=np.sqrt(cov14[0][0])
d_b14=np.sqrt(cov14[1][1])

d_a15=np.sqrt(cov15[0][0])
d_b15=np.sqrt(cov15[1][1])



chisqr=sum((y1-reg_lin(x1,pars[0],pars[1]))**2/ey1**2)
dof = len(y1) - 2

chisqr2=sum((y2-reg_lin(x2,p2pars[0],p2pars[1]))**2/ey2**2)
dof2 = len(y2) - 2

chisqr3=sum((y3-reg_lin(x3,p3pars[0],p3pars[1]))**2/ey3**2)
dof3 = len(y3) - 2

chisqr4=sum((y4-reg_lin(x4,p4pars[0],p4pars[1]))**2/ey4**2)
dof4 = len(y4) - 2

chisqr5=sum((y5-reg_lin(x5,p5pars[0],p5pars[1]))**2/ey5**2)
dof5 = len(y5) - 2

chisqr6=sum((y6-reg_lin(x6,p6pars[0],p6pars[1]))**2/ey6**2)
dof6 = len(y6) - 2

chisqr7=sum((y7-reg_lin(x7,p7pars[0],p7pars[1]))**2/ey7**2)
dof7 = len(y7) - 2

chisqr8=sum((y8-reg_lin(x8,p8pars[0],p8pars[1]))**2/ey8**2)
dof8 = len(y8) - 2

chisqr9=sum((y9-reg_lin(x9,p9pars[0],p9pars[1]))**2/ey9**2)
dof9 = len(y9) - 2

chisqr10=sum((y10-reg_lin(x10,p10pars[0],p10pars[1]))**2/ey10**2)
dof10 = len(y10) - 2

chisqr11=sum((y11-reg_lin(x11,p11pars[0],p11pars[1]))**2/ey11**2)
dof11 = len(y11) - 2

chisqr12=sum((y12-reg_lin(x12,p12pars[0],p12pars[1]))**2/ey12**2)
dof12 = len(y12) - 2

chisqr13=sum((y13-reg_lin(x13,p13pars[0],p13pars[1]))**2/ey13**2)
dof13 = len(y13) - 2

chisqr14=sum((y14-reg_lin(x14,p14pars[0],p14pars[1]))**2/ey14**2)
dof14 = len(y14) - 2

chisqr15=sum((y15-reg_lin(x15,p15pars[0],p15pars[1]))**2/ey15**2)
dof15 = len(y15) - 2

# %%
#=============== Plots ==================

fig,(ax0,ax1,ax2)=plt.subplots(nrows=1, ncols=3, sharex=True,figsize=(15,5))

ax0.set_title('1000 $\mu m$')
ax0.errorbar(x1,y1,yerr=ey1,marker='.',linestyle='none',ms=3)
ax0.errorbar(x4,y4,yerr=ey4,marker='v',linestyle='none',ms=3)
ax0.errorbar(x7,y7,yerr=ey7,marker='^',linestyle='none',ms=3)
ax0.errorbar(x10,y10,yerr=ey10,marker='s',linestyle='none',ms=3)
ax0.errorbar(x13,y13,yerr=ey13,marker='h',linestyle='none',ms=3)

ax0.plot(x1,reg_lin(x1,pars[0],pars[1]),linestyle='solid',color='red',label='CdTe')
ax0.plot(x4,reg_lin(x4,p4pars[0],p4pars[1]),linestyle='solid',color='blue',label='GaAs')
ax0.plot(x7,reg_lin(x7,p7pars[0],p7pars[1]),linestyle='solid',color='green',label='Se')
ax0.plot(x10,reg_lin(x10,p10pars[0],p10pars[1]),linestyle='solid',color='magenta',label='Perovskite')
ax0.plot(x13,reg_lin(x13,p13pars[0],p13pars[1]),linestyle='solid',color='cyan',label='Si')


ax1.set_title('500 $\mu m$')
ax1.errorbar(x2,y2,yerr=ey2,marker='.',linestyle='none',ms=3)
ax1.errorbar(x5,y5,yerr=ey5,marker='v',linestyle='none',ms=3)
ax1.errorbar(x8,y8,yerr=ey8,marker='^',linestyle='none',ms=3)
ax1.errorbar(x11,y11,yerr=ey11,marker='s',linestyle='none',ms=3)
ax1.errorbar(x14,y14,yerr=ey14,marker='h',linestyle='none',ms=3)

ax1.plot(x2,reg_lin(x2,p2pars[0],p2pars[1]),linestyle='solid',color='red',label='CdTe')
ax1.plot(x5,reg_lin(x5,p5pars[0],p5pars[1]),linestyle='solid',color='blue',label='GaAs')
ax1.plot(x8,reg_lin(x8,p8pars[0],p8pars[1]),linestyle='solid',color='green',label='Se')
ax1.plot(x11,reg_lin(x11,p11pars[0],p11pars[1]),linestyle='solid',color='magenta',label='Perovskite')
ax1.plot(x14,reg_lin(x14,p14pars[0],p14pars[1]),linestyle='solid',color='cyan',label='Si')

ax2.set_title('200 $\mu m$')
ax2.errorbar(x3,y3,yerr=ey3,marker='.',linestyle='none',ms=3)
ax2.errorbar(x6,y6,yerr=ey5,marker='v',linestyle='none',ms=3)
ax2.errorbar(x9,y9,yerr=ey8,marker='^',linestyle='none',ms=3)
ax2.errorbar(x12,y12,yerr=ey11,marker='s',linestyle='none',ms=3)
ax2.errorbar(x15,y15,yerr=ey14,marker='h',linestyle='none',ms=3)

ax2.plot(x3,reg_lin(x2,p3pars[0],p3pars[1]),linestyle='solid',color='red',label='CdTe')
ax2.plot(x6,reg_lin(x6,p6pars[0],p6pars[1]),linestyle='solid',color='blue',label='GaAs')
ax2.plot(x9,reg_lin(x9,p9pars[0],p9pars[1]),linestyle='solid',color='green',label='Se')
ax2.plot(x12,reg_lin(x12,p11pars[0],p12pars[1]),linestyle='solid',color='magenta',label='Perovskite')
ax2.plot(x15,reg_lin(x15,p15pars[0],p15pars[1]),linestyle='solid',color='cyan',label='Si')

for ax in ax0,ax1,ax2:
    ax.grid(True)
    ax.set_xlabel('Diameters ($\mu m$)',fontproperties=font)
    ax.set_ylabel('CNR',fontproperties=font,labelpad=1)

#fig.suptitle('Comparing Thicknesses CdTe')


for ax in ax0,ax1,ax2:
    ax.legend()
    
plt.show()
